# %% [markdown]
# # Matplotlib

# %% [markdown]
# # matplotlib is a ploting library
# - its numerically mathematics extension of numpy

# %% [markdown]
# ## advantage of matplotlib
#
# - easy to get started for simple plot.
#
# - easy to customize chart, name, text,or labels ( heading).
#
# - great control on every element in a figures.
#
# - high quality output in many formats.
#
# - vary customizable in general.

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
d={'length':np.random.rand(100)}
df=pd.DataFrame(d)
df
# Out:
#       length
# 0   0.354115
# 1   0.896035
# 2   0.908365
# 3   0.904848
# 4   0.207046
# ..       ...
# 95  0.581315
# 96  0.350518
# 97  0.243985
# 98  0.023531
# 99  0.447215
#
# [100 rows x 1 columns]

# %%
df.shape
# Out:
# (100, 1)

# %% [markdown]
# # histrogram
# - **x axis contain a variable and y axis will be frequency or count of that variable**
#
# - **it is use to check tha given data is normal or not**
# - **skewed or not**

# %%
df['length'].hist() # using pandas
# Out:
# <AxesSubplot:>

# %%
plt.hist(df['length'])
# Out:
# (array([ 6.,  9.,  9., 15.,  6., 13., 13., 13.,  5., 11.]),
#  array([0.00114233, 0.1003587 , 0.19957507, 0.29879145, 0.39800782,
#         0.49722419, 0.59644056, 0.69565694, 0.79487331, 0.89408968,
#         0.99330605]),
#  <BarContainer object of 10 artists>)

# %%
plt.xlabel('length')
# Out:
# Text(0.5, 0, 'length')

# %%
plt.ylabel('frequency/ count')
# Out:
# Text(0, 0.5, 'frequency/ count')

# %%
plt.title('histrogram of length')
# Out:
# Text(0.5, 1.0, 'histrogram of length')

# %%
plt.hist(df['length'])
plt.xlabel('length') # rename the x axis 

plt.ylabel('frequency/ count') # rename the y-axis

plt.title('histrogram of length') # give the title of graph

plt.show()

# %% [markdown]
# - **in histrogram- bars called as bins, by default its 10 bins**

# %%
plt.hist(df['length'],bins=15)
plt.show()

# %% [markdown]
# # Box plot
#
# - **it is used to check the given data has outliers or not**

# %%
plt.boxplot(df['length'])
plt.show()

# %% [markdown]
# # Scatter Plot
#
# - marking the data point on the graph.
# - linearity
#
# - strength
#
# - direction - means if x increse then y- will increase or not

# %%
a=[2,5,9,12,15,17,18,20,22,28,35]
b=[15,8,4,7,9,12,18,11,20,25,26,]
plt.scatter(a,b)
plt.show()

# %%
a=[2,5,8,9,6,3,21,4,7,8,5,7,1,7,8]
c=[10,11,21,12,15,17,18,8,10,9,6,8,13,5,8]
plt.scatter(a,c, c='red', marker='*')
plt.show()

# %% [markdown]
# # line plot

# %% [markdown]
# - in this plot x- value always in sequential order
#
# - syntex:- plt.plot()
#
# - **it is used for time series data**

# %% [markdown]
# - attaching a scatter point in a sequential order is called line plot.
# - by default given value taken as y axis
# - it is used to observed that what is the max & min value

# %%
plt.plot(np.arange(20), c='green', linewidth=4)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('lineplot')
plt.show()

# %%
y=np.random.rand(30)
plt.plot(y)
plt.show()

# %%
a=np.random.rand(20)
b=np.random.rand(20)
plt.grid()
plt.plot(a,b)
plt.show()

# %%
plt.plot([12,8,9,5,4,14,18,19,20,15,8,11,10],color='green')
plt.grid()
plt.show()

# %%
x=np.arange(10)
y=x
z=x**2
a=x**3

# %%
plt.plot(x,y, label='linear',c='red')
plt.legend()
plt.show()

# %%
plt.plot(x,z)

# %%
plt.plot(x,a)

# %% [markdown]
# ## all the data plot in single graph

# %%
plt.plot(x,y, label='liner')
plt.plot(x,z, label='quadratic')
plt.plot(x,a, label='cubical')
plt.legend() # is use to show the line name
plt.show()

# %%
plt.plot([4,8,9,5,4,14,18,19,20,15,8,11,10],color='green')
plt.grid()
plt.text(8,18,'lineplot')
plt.show()

# %%
days=np.arange(1,8)
max_t=np.arange(40,75,5)
min_t=[38,35,37,42,41,30,25]
avg_t=[46,52,54,62,68,43,58]

plt.plot(days,max_t,label='max', linewidth=2)
plt.plot(days,min_t, label='min', linewidth=3)
plt.plot(days,avg_t, label='avg', linewidth=4)

# set axis name and chart title

plt.xlabel('days')
plt.ylabel('Temperature')
plt.title("Weather")
plt.legend()
plt.show()

# %%
days=np.arange(1,8)
max_t=np.arange(40,75,5)
min_t=[38,35,37,42,41,30,25]
avg_t=[46,52,54,62,68,43,58]

plt.plot(days,max_t,label='max', linewidth=2)
plt.plot(days,min_t, label='min', linewidth=3)
plt.plot(days,avg_t, label='avg', linewidth=3)

# set axis name and chart title

plt.xlabel('days')
plt.ylabel('Temperature')
plt.title("Weather")

plt.text(4,50,'lineplot') # text as per specific position

plt.grid() # grid 

plt.legend() # to show line name
plt.show()

# %% [markdown]
# # Subplot

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

plt.subplot(3,2,1)
plt.plot(x,y, c='red',marker='*', linestyle='dashed')
plt.title('Line plot')

plt.subplot(3,2,2)
plt.scatter(x,y)
plt.title('Scatter plot')

plt.subplot(3,2,3)
plt.plot(x,y, linewidth=3)

plt.subplot(3,2,6)
plt.plot(x,y,c='green',marker='o', linestyle='dashed')
plt.show()

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

plt.subplot(2,2,1)
plt.plot(x,y, c='red',marker='*', linestyle='dashed')
plt.title('Line plot')

plt.subplot(2,2,2)
plt.scatter(x,y)
plt.title('Scatter plot')

plt.subplot(2,2,4)
plt.plot(x,y, linewidth=3)

plt.subplot(2,2,3)
plt.plot(x,y,c='green',marker='o', linestyle='dashed')
plt.show()

# %% [markdown]
# # contineous data - analysis
# - **uni variate -- histrogram and box plot are used**
#
# - **bivariate --- scatter plot are used**
#
# - **multi variate -- heat map and pair plot are used in 'seaborn library'**
#
# # time series data - line plot are used
#
# # discrete data analysis - bar chart and pie chart are used.

# %% [markdown]
# # Pie chart

# %%
list=[20,30,15,10,20,5]

lbs=['facecream','facewash','toothpaste','soap','sampoo','moisture ']

plt.pie(list, labels=lbs, autopct='%1.1f%%',radius=1.5, explode=(0,0.3,0,0,0,0.2))

plt.show()

# %%
# counter clock and angle properties
plt.pie(list, labels=lbs, autopct='%1.1f%%',explode=(0,0.1,0,0,0,0),counterclock='False',startangle=90)
plt.axis('equal')

plt.show()

# %% [markdown]
# ## data to plot

# %%
la=['python','c++','jave','ruby']
sizes=[35,30,20,15]
color=['gold','blue','pink','purple']
plt.pie(sizes,labels=la,colors=color,radius=1.5,autopct='%1.1f%%')
plt.show()

# %%
la=['deep','panda','jany','lado']
sizes=[50,35,15,40]
color=['gold','blue','green','red']
explode=(0.1,0,0.1,0)
plt.pie(sizes,labels=la,explode=explode,colors=color,radius=1.5,autopct='%1.1f%%')
plt.savefig('piechart.jpg')
plt.show()

# %% [markdown]
# # Bar Plot

# %% [markdown]
# - **it describe the comparison  between the discrete categorical data**
# - **it can be ploted both horizontally and vertically**

# %%
company=['google','amazon','myntra','fb']
revenue=[90,136,85,27]
plt.bar(company,revenue)
plt.ylabel('revenue $')
plt.title('us technology stock')
plt.show()

# %% [markdown]
# # for horizontal bar plot

# %%
company=['google','amazon','myntra','fb']
revenue=[90,136,85,27]
plt.barh(company,revenue)
plt.xlabel('revenue $')
plt.title('us technology stock')
plt.show()

# %%
list=[20,30,15,10,20,5]

lbs=['facecream','facewash','toothpaste','soap','sampoo','moisture ']

plt.bar(lbs,list)

plt.show()

# %%
la=['python','c++','jave','ruby']
sizes=[35,30,20,15]
plt.bar(la,sizes)
plt.show()

# %% [markdown]
# # Stack bar plot

# %%
company=['google','amazon','myntra','fb']
revenue=[90,136,85,27]
profit=[40,20,34,12]
plt.bar(company,revenue, label='revenue')
plt.bar(company,profit, label='profit')
plt.title('us technology stock')
plt.legend()
plt.show()

# %% [markdown]
# # ploting bar graph seperately in both revenue and profit in one graph

# %%
company=['google','amazon','myntra','fb']
revenue=[90,136,85,27]
profit=[40,20,34,12]
xpos=np.arange(len(company))

plt.bar(xpos-0.2,revenue,width=0.4,label='revenue')
plt.bar(xpos+.2,profit,width=0.4,label='profit')

plt.xticks(xpos,company) # used to specify the company bar name
plt.ylabel('revenue')

plt.title('us technology stock')
plt.legend()
plt.show()

# %% [markdown]
# # creating different bar-chart in one images

# %%
company=['myntra','flipkart','amazon','alibaba','snapdeal']

plt.figure(1,figsize=(15,15))
q1_profit=[80,120,50,68,90]
q2_profit=[38,40,105,65,80]
q3_profit=[40,80,75,55,110]
q4_profit=[75,61,90,105,115]

plt.subplot(3,2,1)
plt.bar(company,q1_profit)
plt.title('quarter1 profit')

plt.subplot(3,2,2)
plt.pie(q2_profit,labels=company,autopct='%1.1f%%')
plt.title('quarter2 profit')


plt.subplot(3,2,3)
plt.pie(q3_profit,labels=company,autopct='%1.1f%%',radius=1,explode=(0,0.1,0,0,0) )
plt.title('quarter3 profit')

plt.subplot(3,2,5)
plt.bar(company,q3_profit)
plt.title('quarter3 profit')

plt.subplot(3,2,4)
plt.bar(company,q4_profit)
plt.title('quarter4 profit')
plt.savefig('subplot.jpg')
plt.show()

# %%
company=['myntra','flipkart','amazon','alibaba','snapdeal']

plt.figure(1,figsize=(10,15))

q1_profit=[80,120,50,68,90]
q2_profit=[38,40,105,65,80]
q3_profit=[40,80,75,55,110]
q4_profit=[75,61,90,105,115]

plt.subplot(2,2,1)
plt.bar(company,q1_profit)
plt.title('quarter1 profit')

plt.subplot(2,2,2)
plt.bar(company,q2_profit)
plt.title('quarter2 profit')

plt.subplot(2,2,3)
plt.bar(company,q3_profit)
plt.title('quarter3 profit')

plt.subplot(2,2,4)
plt.bar(company,q4_profit)
plt.title('quarter4 profit')

plt.suptitle('profit on quarterly basis')
plt.show()
